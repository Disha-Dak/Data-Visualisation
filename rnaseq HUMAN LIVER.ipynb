# %%
import pandas as pd   #importing package

# %%
df = pd.read_csv("human_liver.tsv",sep = "\t")  #reading the tab seperated file

# %%
df
# Out:
#               genes  GSM742944  GSM2326089  GSM1807974  GSM1807990  \
# 0              A1BG          0          92       11663        2089
# 1              A1CF          0          17        5738         490
# 2               A2M       6362         304       39269        8299
# 3             A2ML1          0          22          11           2
# 4             A2MP1          0           3         167           7
# ...             ...        ...         ...         ...         ...
# 35233  BP-2171C21.4          0           0           0           0
# 35234  BP-2171C21.5          0           0           0           0
# 35235  BP-2171C21.6          0           4           1           0
# 35236   BP-2189O9.2          0          25           6           0
# 35237    YR211F11.2          0           0           0           0
#
#        GSM2055788  GSM2142335  GSM1807979  GSM1695909  GSM1554468  ...  \
# 0           18808         183        5123       79640        1595  ...
# ...

# %%
df.describe()
# Out:
#           GSM742944     GSM2326089     GSM1807974    GSM1807990    GSM2055788  \
# count  35238.000000   35238.000000   35238.000000  35238.000000  3.523800e+04
# mean       9.136245    1499.294171     473.682473     82.726971  4.680936e+02
# std      211.284156    8817.639459    3415.314857   1193.182428  7.613447e+03
# min        0.000000       0.000000       0.000000      0.000000  0.000000e+00
# 25%        0.000000       0.000000       0.000000      0.000000  0.000000e+00
# 50%        0.000000       6.000000       2.000000      0.000000  9.000000e+00
# 75%        0.000000     971.000000     261.000000      6.000000  2.020000e+02
# max    22408.000000  705513.000000  241197.000000  99555.000000  1.150608e+06
#
#          GSM2142335     GSM1807979    GSM1695909    GSM1554468    GSM1695910  \
# count  3.523800e+04   35238.000000  3.523800e+04  3.523800e+04  3.523800e+04
# mean   5.455975e+02     280.928174  1.572038e+03  3.197678e+02  1.868345e+03
# ...

# %%
df[df["GSM742944"] > df["GSM742944"].mean()]
# Out:
#         genes  GSM742944  GSM2326089  GSM1807974  GSM1807990  GSM2055788  \
# 2         A2M       6362         304       39269        8299       20260
# 21       AAMP         75        5180         807           0        1006
# 25       AARS        168        6478        1431         526        1280
# 32       AATF         12        4430         452          68         306
# 37       ABAT         89        2772        3836         501       11581
# ...       ...        ...         ...         ...         ...         ...
# 35107  ZNF841         10           7         205           0         266
# 35213  ZSWIM8         25        2273        2433         140        1631
# 35220    ZXDC         16        1628        1222           6         853
# 35226   ZZEF1         40        3699        1121          68        1757
# 35227    ZZZ3         15        3462         636           1        1147
#
#        GSM2142335  GSM1807979  GSM1695909  GSM1554468  ...  GSM2653842  \
# ...

# %%
df.groupby("genes").agg({"GSM1807974" : ["sum"]})
# Out:
#        GSM1807974
#               sum
# genes
# A1BG        11663
# A1CF         5738
# A2M         39269
# A2ML1          11
# A2MP1         167
# ...           ...
# ZYG11B        859
# ZYX          2391
# ZYXP1           0
# ZZEF1        1121
# ZZZ3          636
#
# [35238 rows x 1 columns]

# %%
df1 = pd.concat([df,df]) #two data frames

# %%
df1
# Out:
#               genes  GSM742944  GSM2326089  GSM1807974  GSM1807990  \
# 0              A1BG          0          92       11663        2089
# 1              A1CF          0          17        5738         490
# 2               A2M       6362         304       39269        8299
# 3             A2ML1          0          22          11           2
# 4             A2MP1          0           3         167           7
# ...             ...        ...         ...         ...         ...
# 35233  BP-2171C21.4          0           0           0           0
# 35234  BP-2171C21.5          0           0           0           0
# 35235  BP-2171C21.6          0           4           1           0
# 35236   BP-2189O9.2          0          25           6           0
# 35237    YR211F11.2          0           0           0           0
#
#        GSM2055788  GSM2142335  GSM1807979  GSM1695909  GSM1554468  ...  \
# 0           18808         183        5123       79640        1595  ...
# ...

# %%
df1.groupby("genes").agg({"GSM1807974" : ["sum"]})  #sum is doubled than the above
# Out:
#        GSM1807974
#               sum
# genes
# A1BG        23326
# A1CF        11476
# A2M         78538
# A2ML1          22
# A2MP1         334
# ...           ...
# ZYG11B       1718
# ZYX          4782
# ZYXP1           0
# ZZEF1        2242
# ZZZ3         1272
#
# [35238 rows x 1 columns]

# %%
df1.groupby("genes").agg({"GSM1807974" : ["sum","mean"]})
# Out:
#        GSM1807974
#               sum     mean
# genes
# A1BG        23326  11663.0
# A1CF        11476   5738.0
# A2M         78538  39269.0
# A2ML1          22     11.0
# A2MP1         334    167.0
# ...           ...      ...
# ZYG11B       1718    859.0
# ZYX          4782   2391.0
# ZYXP1           0      0.0
# ZZEF1        2242   1121.0
# ZZZ3         1272    636.0
#
# [35238 rows x 2 columns]

# %%
df.T   #Transpose-rows and column is interchanged
# Out:
#             0     1      2      3      4        5       6      7     8      \
# genes        A1BG  A1CF    A2M  A2ML1  A2MP1  A3GALT2  A4GALT  A4GNT  AAAS
# GSM742944       0     0   6362      0      0        0       0      0     0
# GSM2326089     92    17    304     22      3        0     422     20  2319
# GSM1807974  11663  5738  39269     11    167        1      78      4   593
# GSM1807990   2089   490   8299      2      7        0       0      1    13
# ...           ...   ...    ...    ...    ...      ...     ...    ...   ...
# GSM2653847     12     5      0      6      0        0      51      0   321
# GSM2653849      8     8      4      3      0        0      34      0   247
# GSM2653850      6     4      1      3      0        0      25      0   204
# GSM2653851     10     2      3      3      0        0      31      0   212
# GSM2653853      8    24      1      1      0        0       2      0   104
#
# ...

# %%
df_1 = df.set_index("genes")

# %%
df_1
# Out:
#               GSM742944  GSM2326089  GSM1807974  GSM1807990  GSM2055788  \
# genes
# A1BG                  0          92       11663        2089       18808
# A1CF                  0          17        5738         490       14035
# A2M                6362         304       39269        8299       20260
# A2ML1                 0          22          11           2          39
# A2MP1                 0           3         167           7          44
# ...                 ...         ...         ...         ...         ...
# BP-2171C21.4          0           0           0           0           0
# BP-2171C21.5          0           0           0           0           8
# BP-2171C21.6          0           4           1           0           1
# BP-2189O9.2           0          25           6           0          48
# YR211F11.2            0           0           0           0           0
#
#               GSM2142335  GSM1807979  GSM1695909  GSM1554468  GSM1695910  ...  \
# ...

# %%
df_1.T
# Out:
# genes        A1BG   A1CF    A2M  A2ML1  A2MP1  A3GALT2  A4GALT  A4GNT  AAAS  \
# GSM742944       0      0   6362      0      0        0       0      0     0
# GSM2326089     92     17    304     22      3        0     422     20  2319
# GSM1807974  11663   5738  39269     11    167        1      78      4   593
# GSM1807990   2089    490   8299      2      7        0       0      1    13
# GSM2055788  18808  14035  20260     39     44        0      69      3   237
# ...           ...    ...    ...    ...    ...      ...     ...    ...   ...
# GSM2653847     12      5      0      6      0        0      51      0   321
# GSM2653849      8      8      4      3      0        0      34      0   247
# GSM2653850      6      4      1      3      0        0      25      0   204
# GSM2653851     10      2      3      3      0        0      31      0   212
# GSM2653853      8     24      1      1      0        0       2      0   104
#
# ...

# %%
df.columns  #index =-1
# Out:
# Index(['genes', 'GSM742944', 'GSM2326089', 'GSM1807974', 'GSM1807990',
#        'GSM2055788', 'GSM2142335', 'GSM1807979', 'GSM1695909', 'GSM1554468',
#        ...
#        'GSM2653842', 'GSM2653843', 'GSM2653844', 'GSM2653845', 'GSM2653846',
#        'GSM2653847', 'GSM2653849', 'GSM2653850', 'GSM2653851', 'GSM2653853'],
#       dtype='object', length=904)

# %%
len(df.columns)-1   #first column is index
# Out:
# 903

# %%
data = {"genes": ["AZM", "AAMP", "A2M"]}

# Convert to a DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#   genes
# 0   AZM
# 1  AAMP
# 2   A2M

# %%
df_3 = pd.DataFrame(data)

# %%
df_3
# Out:
#   genes
# 0   AZM
# 1  AAMP
# 2   A2M

# %%
df_3.merge(df_1,on="genes")
# Out:
#   genes  GSM742944  GSM2326089  GSM1807974  GSM1807990  GSM2055788  \
# 0  AAMP         75        5180         807           0        1006
# 1   A2M       6362         304       39269        8299       20260
#
#    GSM2142335  GSM1807979  GSM1695909  GSM1554468  ...  GSM2653842  \
# 0         172         336        4162         576  ...         559
# 1          97       27210       63297        5817  ...           8
#
#    GSM2653843  GSM2653844  GSM2653845  GSM2653846  GSM2653847  GSM2653849  \
# 0         675         684         621         579        1697        1413
# 1           6           2           0         374           0           4
#
#    GSM2653850  GSM2653851  GSM2653853
# 0        1453        1308         376
# 1           1           3           1
#
# [2 rows x 904 columns]

# %%
# !pip install matplotlib

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.9.2

# %%
#line plot
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("human_liver.tsv",sep = "\t")

# %%
df
# Out:
#               genes  GSM742944  GSM2326089  GSM1807974  GSM1807990  \
# 0              A1BG          0          92       11663        2089
# 1              A1CF          0          17        5738         490
# 2               A2M       6362         304       39269        8299
# 3             A2ML1          0          22          11           2
# 4             A2MP1          0           3         167           7
# ...             ...        ...         ...         ...         ...
# 35233  BP-2171C21.4          0           0           0           0
# 35234  BP-2171C21.5          0           0           0           0
# 35235  BP-2171C21.6          0           4           1           0
# 35236   BP-2189O9.2          0          25           6           0
# 35237    YR211F11.2          0           0           0           0
#
#        GSM2055788  GSM2142335  GSM1807979  GSM1695909  GSM1554468  ...  \
# 0           18808         183        5123       79640        1595  ...
# ...

# %%
plt.figure(figsize=(8,5))
plt.plot(df["GSM742944"],df["GSM2326089"],marker="o",) #marker= the dots #X = x
plt.title("Line PLot")
plt.xlabel("GSM742944")
plt.ylabel("GSM2326089")
plt.grid()
plt.show()#lineplot=plot

# %%
plt.figure(figsize=(8,5))#no lines to connect the dots
plt.scatter(df["GSM742944"],df["GSM2326089"],marker="o",) #marker= the dots
plt.title("Scatter PLot")
plt.xlabel("GSM742944")
plt.ylabel("GSM2326089")
plt.grid()
plt.show()#lineplot=scatter

# %%
ds
# Out:
#      genes  GSM742944  GSM2326089  GSM1807974  GSM1807990  GSM2055788  \
# 0     A1BG          0          92       11663        2089       18808
# 1     A1CF          0          17        5738         490       14035
# 2      A2M       6362         304       39269        8299       20260
# 3    A2ML1          0          22          11           2          39
# 4    A2MP1          0           3         167           7          44
# 5  A3GALT2          0           0           1           0           0
# 6   A4GALT          0         422          78           0          69
# 7    A4GNT          0          20           4           1           3
# 8     AAAS          0        2319         593          13         237
# 9     AACS          1        4365         374          18         243
#
#    GSM2142335  GSM1807979  GSM1695909  GSM1554468  ...  GSM2653842  \
# 0         183        5123       79640        1595  ...          30
# ...

# %%
ds.iloc[:10]
# Out:
#          GSM742944  GSM2326089  GSM1807974  GSM1807990  GSM2055788  \
# genes
# A1BG             0          92       11663        2089       18808
# A1CF             0          17        5738         490       14035
# A2M           6362         304       39269        8299       20260
# A2ML1            0          22          11           2          39
# A2MP1            0           3         167           7          44
# A3GALT2          0           0           1           0           0
# A4GALT           0         422          78           0          69
# A4GNT            0          20           4           1           3
# AAAS             0        2319         593          13         237
# AACS             1        4365         374          18         243
#
#          GSM2142335  GSM1807979  GSM1695909  GSM1554468  GSM1695910  ...  \
# genes                                                                ...
# A1BG            183        5123       79640        1595       23761  ...
# ...

# %%
ds = df.iloc[:10]

# %%
ds
# Out:
#      genes  GSM742944  GSM2326089  GSM1807974  GSM1807990  GSM2055788  \
# 0     A1BG          0          92       11663        2089       18808
# 1     A1CF          0          17        5738         490       14035
# 2      A2M       6362         304       39269        8299       20260
# 3    A2ML1          0          22          11           2          39
# 4    A2MP1          0           3         167           7          44
# 5  A3GALT2          0           0           1           0           0
# 6   A4GALT          0         422          78           0          69
# 7    A4GNT          0          20           4           1           3
# 8     AAAS          0        2319         593          13         237
# 9     AACS          1        4365         374          18         243
#
#    GSM2142335  GSM1807979  GSM1695909  GSM1554468  ...  GSM2653842  \
# 0         183        5123       79640        1595  ...          30
# ...

# %%
plt.figure(figsize=(8,5))
plt.bar(ds["genes"],ds["GSM2326089"]) #marker= the dots
plt.title("bar plot")
plt.xlabel("genes")
plt.ylabel("GSM2326089")
plt.grid()
plt.show()#lineplot=plot

# %%
plt.figure(figsize=(8,5))
plt.plot(ds["genes"],ds["GSM2326089"]) #marker= the dots
plt.title("line plot")
plt.xlabel("genes")
plt.ylabel("GSM2326089")
plt.grid()
plt.show()#lineplot=plot

# %%
ds=df.set_index("genes")

# %%
ds=ds.T

# %%
ds
# Out:
# genes        A1BG   A1CF    A2M  A2ML1  A2MP1  A3GALT2  A4GALT  A4GNT  AAAS  \
# GSM742944       0      0   6362      0      0        0       0      0     0
# GSM2326089     92     17    304     22      3        0     422     20  2319
# GSM1807974  11663   5738  39269     11    167        1      78      4   593
# GSM1807990   2089    490   8299      2      7        0       0      1    13
# GSM2055788  18808  14035  20260     39     44        0      69      3   237
# ...           ...    ...    ...    ...    ...      ...     ...    ...   ...
# GSM2653847     12      5      0      6      0        0      51      0   321
# GSM2653849      8      8      4      3      0        0      34      0   247
# GSM2653850      6      4      1      3      0        0      25      0   204
# GSM2653851     10      2      3      3      0        0      31      0   212
# GSM2653853      8     24      1      1      0        0       2      0   104
#
# ...

# %%
plt.figure(figsize=(8,5))
plt.plot(ds["A1BG"],ds["A1CF"],marker="x",) #marker= the dots 
plt.title("Line PLot")
plt.xlabel("A1BG")
plt.ylabel("A1CF")
plt.grid()
plt.show()#lineplot=plot

# %%
plt.figure(figsize=(8,5))
plt.scatter(ds["A1BG"],ds["A1CF"],marker="x",) #marker= the dots 
plt.title("Line PLot")
plt.xlabel("A1BG")
plt.ylabel("A1CF")
plt.grid()
plt.show()#lineplot=plot

# %%
da = ds.sort_values(by="A1BG", ascending=False)

# %%
da
# Out:
# genes         A1BG   A1CF     A2M  A2ML1  A2MP1  A3GALT2  A4GALT  A4GNT  AAAS  \
# GSM1067795  220448  19447  804229     41    367        2     292     11  2549
# GSM1538081  158054  10749  224482     46    203       10     549     14  2550
# GSM1538089  141619   9012  185275     23    144        7     319      0  1540
# GSM1538091  140451  17343  135955     35     68        2     156     20  1937
# GSM1538093  118168  15854  116393     19     98        1     145     16  2366
# ...            ...    ...     ...    ...    ...      ...     ...    ...   ...
# GSM2547320       0      0       0      0      0        0       0      0     1
# GSM2547322       0      1      14      3      0        0       0      0     0
# GSM2547323       0      0      62      0      0        0       0      0   379
# GSM2547325       0    164       1      0      0        0       0      0    33
# GSM742944        0      0    6362      0      0        0       0      0     0
#
# ...

# %%
da=da.reset_index()

# %%
da=da.iloc[:10]

# %%
plt.figure(figsize=(15,15))
plt.bar(da["index"],da["A1BG"]) #marker= the dots
plt.title("bar plot")
plt.xlabel("index")
plt.ylabel("A1BG")

plt.show()#lineplot=plot

# %%
pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip3 install plotly

# %%
pip show plotly
# Out:
# WARNING: Package(s) not found: plotly
# Note: you may need to restart the kernel to use updated packages.
